# %%
import pandas as pd
import numpy as np
import openpyxl

# %%
zakladki = pd.read_excel('Lista uczniów SP_LO_2022_2023 propozycje ocen rocznych.xlsx', sheet_name=None).keys()
zakladki
# Out:
# dict_keys(['1 SP uzup', '1 SP ram', '2 SP uzup', '2 SP ram', '3 SP uzup', '3 SP ram', '4 SP ram', '4 SP uzup', '5 SP uzup', '5 SP ram', '6 SP ram', '6 SP uzup', '7 SP uzup', '8 SP uzup', '7 SP ram', '8 SP ram', '1 LO uzup', '1 LO ram', '2 LO ram', '2 LO uzup', '3 LO uzup', '3 LO ram', '4 LO uzup', 'Arkusz1'])

# %%
zakladki = ['1 SP uzup', '1 SP ram', '2 SP uzup', '2 SP ram', '3 SP uzup', '3 SP ram', '4 SP ram', '4 SP uzup', '5 SP uzup', '5 SP ram', '6 SP ram', '6 SP uzup', '7 SP uzup', '8 SP uzup', '7 SP ram', '8 SP ram', '1 LO uzup', '1 LO ram', '2 LO ram', '2 LO uzup', '3 LO uzup', '3 LO ram', '4 LO uzup']
zakladki.sort()
# zakladki

# %%
df = pd.concat(pd.read_excel('Lista uczniów SP_LO_2022_2023 propozycje ocen rocznych.xlsx', sheet_name=s, usecols='B:E', skiprows=1).assign(Klasa = s) for s in zakladki)

# %%
df.columns
# Out:
# Index(['L.p.', 'Nazwisko ucznia', 'Imię/Imiona', 'e-mail', 'Klasa'], dtype='object')

# %%
df.dropna(subset=['L.p.', 'Nazwisko ucznia'], inplace = True)

# %%
df.drop_duplicates(subset=['Nazwisko ucznia', 'Imię/Imiona','Klasa'])
df
# Out:
#     L.p.   Nazwisko ucznia         Imię/Imiona  \
# 1    1.0         Bembnista               Dawid
# 2    2.0         Bryliński              Bogdan
# 3    3.0  Chicińska-Ryster              Nikola
# 4    4.0             Ciźla               Nadia
# 5    5.0         Czarnocka           Nikoletta
# ..   ...               ...                 ...
# 91  91.0      Łapicz-Biedź      Zachary Oliver
# 92  92.0             Łoboz        Julia Danuta
# 93  93.0         Śladewski              Antoni
# 94  94.0         Żukrowska  Anastazja Apolonia
# 95  95.0       Lenkiewicz              Zuzanna
#
#                                    e-mail      Klasa
# 1   jolbem1978@gmail.com   tombem30@wp.pl   1 LO ram
# 2               contact@olgabrylinska.com   1 LO ram
# 3                       izabela2169@wp.pl   1 LO ram
# 4                       cpn.fit@gmail.com   1 LO ram
# 5                          tamara.c@wp.pl   1 LO ram
# ..                                    ...        ...
# 91                       wbiedz@gmail.com  8 SP uzup
# 92                         gwiazdap@op.pl  8 SP uzup
# 93             jacek.sladewski@msz.gov.pl  8 SP uzup
# 94                k.a.zukrowska@gmail.com  8 SP uzup
# 95                     anka_jak@yahoo.com  8 SP uzup
#
# [1625 rows x 5 columns]

# %%
df.loc[df['Klasa']=='8 SP uzup']
# Out:
#     L.p. Nazwisko ucznia         Imię/Imiona                        e-mail  \
# 1    1.0     Abdel Kader    Yasmin Magdalena  agnieszka.kozlowska@mail.com
# 2    2.0   Abdelmouatty                 Omar  sahar.hussein2009@yahoo.com
# 3    3.0       Andruchów             Mikołaj          agandruchow@yahoo.pl
# 4    4.0        Bartczak    Nikodem Wojciech              bartczak18@o2.pl
# 5    5.0     Bartkiewicz                 Jan            ewabart5@gmail.com
# ..   ...             ...                 ...                           ...
# 91  91.0    Łapicz-Biedź      Zachary Oliver              wbiedz@gmail.com
# 92  92.0           Łoboz        Julia Danuta                gwiazdap@op.pl
# 93  93.0       Śladewski              Antoni    jacek.sladewski@msz.gov.pl
# 94  94.0       Żukrowska  Anastazja Apolonia       k.a.zukrowska@gmail.com
# 95  95.0     Lenkiewicz              Zuzanna            anka_jak@yahoo.com
#
#         Klasa
# 1   8 SP uzup
# 2   8 SP uzup
# 3   8 SP uzup
# 4   8 SP uzup
# 5   8 SP uzup
# ..        ...
# 91  8 SP uzup
# 92  8 SP uzup
# 93  8 SP uzup
# 94  8 SP uzup
# 95  8 SP uzup
#
# [95 rows x 5 columns]

# %%
dbzakladki = pd.read_excel('Uczniowie KNO 2022-2023 - aktualna — kopia.xlsx', sheet_name=None).keys()

# %%
dbzakladki= list(dbzakladki)
dbzakladki.sort()
dbzakladki
# Out:
# ['1 LO ram',
#  '1 LO uzup',
#  '1 sp ram',
#  '1 sp uzup',
#  '2 LO ram',
#  '2 LO uzup',
#  '2 sp ram',
#  '2 sp uzup',
#  '3 LO ram',
#  '3 LO uzup',
#  '3 sp ram',
#  '3 sp uzup',
#  '4 LO ram',
#  '4 LO uzup',
#  '4 sp ram',
#  '4 sp uzup',
#  '5 sp ram',
#  '5 sp uzup',
#  '6 sp ram',
#  '6 sp uzup',
#  '7 sp ram',
#  '7 sp uzup',
#  '8 sp ram',
#  '8 sp uzup',
#  'Arkusz1',
#  'Arkusz2',
#  'Podsumowanie',
#  'Teams uczniowie ALL',
#  'Zespoły w Teams']

# %%
dbzakladki = ['1 LO ram',
 '1 LO uzup',
 '1 sp ram',
 '1 sp uzup',
 '2 LO ram',
 '2 LO uzup',
 '2 sp ram',
 '2 sp uzup',
 '3 LO ram',
 '3 LO uzup',
 '3 sp ram',
 '3 sp uzup',
 '4 LO ram',
 '4 LO uzup',
 '4 sp ram',
 '4 sp uzup',
 '5 sp ram',
 '5 sp uzup',
 '6 sp ram',
 '6 sp uzup',
 '7 sp ram',
 '7 sp uzup',
 '8 sp ram',
 '8 sp uzup']

# %%
db = pd.concat(pd.read_excel('Uczniowie KNO 2022-2023 - aktualna — kopia.xlsx', usecols='A:L', sheet_name = s).assign(Klasa = s) for s in dbzakladki)

# %%
db.columns
# Out:
# Index(['L.p.', 'Nazwisko ucznia', 'Imię ucznia', 'Drugie imię ucznia',
#        'nr ksiegi', 'Data urodzenia ucznia', 'Miejsce urodzen..',
#        'PESEL ucznia', 'Inny dokument t..', 'Nr i seria doku..',
#        'Kraj pobytu ucznia', 'Email', 'Klasa'],
#       dtype='object')

# %%
db
# Out:
#       L.p.   Nazwisko ucznia Imię ucznia Drugie imię ucznia nr ksiegi  \
# 0        1       Staśkiewicz        Anna          Magdalena      4149
# 1        2  Chicińska-Ryster      Nikola             Żaneta      4150
# 2        3            Papież    Kristian               Alan      4151
# 3        4           Kukieła      Amelia          Magdalena      4152
# 4        5            Patacz      Amelia          Michalina      1853
# ..     ...               ...         ...                ...       ...
# 98    99.0        Włodraczyk    Wiktoria                NaN      4060
# 99   100.0         Yalovskyi    Yaroslav                NaN      4061
# 100  101.0         Krawczak      Matthew              Peter      4062
# 101  102.0       Lenkiewicz      Zuzanna                NaN      4063
# 102  103.0       Radzimiński        Igor                NaN      4624
#
#     Data urodzenia ucznia         Miejsce urodzen.. PESEL ucznia  \
# 0     2007-12-07 00:00:00                      Piła   7320704782
# 1     2008-04-14 00:00:00      CHESTERFIELD ENGLAND   8241412527
# 2     2007-12-10 00:00:00  Reykjanesbaer - Islandia          NaN
# 3     2007-10-30 00:00:00             Bielsko-Biała   7303002809
# 4     2007-04-16 00:00:00            POLANICA ZDRÓJ   7241601308
# ..                    ...                       ...          ...
# 98    2008-04-27 00:00:00                     Wałcz   8242702500
# 99    2008-11-21 00:00:00                     Kijów   8312114459
# 100   2008-03-04 00:00:00                 ST.Thomas   8230413375
# 101   2008-05-09 00:00:00                   Londyn    8250912500
# 102   2009-04-12 00:00:00                  Warszawa   9241206590
#
#              Inny dokument t.. Nr i seria doku.. Kraj pobytu ucznia  \
# 0                          NaN               NaN             Niemcy
# 1                          NaN               NaN    Wielka Brytania
# 2                     Paszport         ER0669334           Islandia
# 3                          NaN               NaN             Polska
# 4    Inny dokument ze zdjęciem         CCF287398            Szwecja
# ..                         ...               ...                ...
# 98                         NaN               NaN             Turcja
# 99                         NaN               NaN            Ukraina
# 100                        NaN               NaN             Kanada
# 101                        NaN               NaN    Wielka Brytania
# 102                        NaN               NaN             Moskwa
#
#                                        Email      Klasa
# 0                     alinastaskiewicz@o2.pl   1 LO ram
# 1                              strati-matyja   1 LO ram
# 2                    kristiano2007@gmail.com   1 LO ram
# 3                                magda@wp.eu   1 LO ram
# 4                            edzia1703@o2.pl   1 LO ram
# ..                                       ...        ...
# 98                                       NaN  8 sp uzup
# 99   juliajalov@gmail.com;fogartu@qulook.com  8 sp uzup
# 100                    leskrawczak@Gmail.com  8 sp uzup
# 101                       anka_jak@yahoo.com  8 sp uzup
# 102                      a.radziminska@wp.pl  8 sp uzup
#
# [1877 rows x 13 columns]

# %%
db.dropna(subset=['L.p.'], inplace = True)

# %%
db.drop_duplicates(subset=['Nazwisko ucznia', 'Imię ucznia', 'Klasa'], inplace = True)

# %%
db
# Out:
#       L.p.   Nazwisko ucznia Imię ucznia Drugie imię ucznia nr ksiegi  \
# 0        1       Staśkiewicz        Anna          Magdalena      4149
# 1        2  Chicińska-Ryster      Nikola             Żaneta      4150
# 2        3            Papież    Kristian               Alan      4151
# 3        4           Kukieła      Amelia          Magdalena      4152
# 4        5            Patacz      Amelia          Michalina      1853
# ..     ...               ...         ...                ...       ...
# 98    99.0        Włodraczyk    Wiktoria                NaN      4060
# 99   100.0         Yalovskyi    Yaroslav                NaN      4061
# 100  101.0         Krawczak      Matthew              Peter      4062
# 101  102.0       Lenkiewicz      Zuzanna                NaN      4063
# 102  103.0       Radzimiński        Igor                NaN      4624
#
#     Data urodzenia ucznia         Miejsce urodzen.. PESEL ucznia  \
# 0     2007-12-07 00:00:00                      Piła   7320704782
# 1     2008-04-14 00:00:00      CHESTERFIELD ENGLAND   8241412527
# 2     2007-12-10 00:00:00  Reykjanesbaer - Islandia          NaN
# 3     2007-10-30 00:00:00             Bielsko-Biała   7303002809
# 4     2007-04-16 00:00:00            POLANICA ZDRÓJ   7241601308
# ..                    ...                       ...          ...
# 98    2008-04-27 00:00:00                     Wałcz   8242702500
# 99    2008-11-21 00:00:00                     Kijów   8312114459
# 100   2008-03-04 00:00:00                 ST.Thomas   8230413375
# 101   2008-05-09 00:00:00                   Londyn    8250912500
# 102   2009-04-12 00:00:00                  Warszawa   9241206590
#
#              Inny dokument t.. Nr i seria doku.. Kraj pobytu ucznia  \
# 0                          NaN               NaN             Niemcy
# 1                          NaN               NaN    Wielka Brytania
# 2                     Paszport         ER0669334           Islandia
# 3                          NaN               NaN             Polska
# 4    Inny dokument ze zdjęciem         CCF287398            Szwecja
# ..                         ...               ...                ...
# 98                         NaN               NaN             Turcja
# 99                         NaN               NaN            Ukraina
# 100                        NaN               NaN             Kanada
# 101                        NaN               NaN    Wielka Brytania
# 102                        NaN               NaN             Moskwa
#
#                                        Email      Klasa
# 0                     alinastaskiewicz@o2.pl   1 LO ram
# 1                              strati-matyja   1 LO ram
# 2                    kristiano2007@gmail.com   1 LO ram
# 3                                magda@wp.eu   1 LO ram
# 4                            edzia1703@o2.pl   1 LO ram
# ..                                       ...        ...
# 98                                       NaN  8 sp uzup
# 99   juliajalov@gmail.com;fogartu@qulook.com  8 sp uzup
# 100                    leskrawczak@Gmail.com  8 sp uzup
# 101                       anka_jak@yahoo.com  8 sp uzup
# 102                      a.radziminska@wp.pl  8 sp uzup
#
# [1724 rows x 13 columns]

# %%
db['Data urodzenia ucznia'] = pd.to_datetime(db['Data urodzenia ucznia'], errors='coerce')
# Out:
# C:\Users\WojciechBalcerzak\AppData\Local\Temp\ipykernel_10600\1309943092.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   db['Data urodzenia ucznia'] = pd.to_datetime(db['Data urodzenia ucznia'], errors='coerce')

# %%
db
# Out:
#       L.p.   Nazwisko ucznia Imię ucznia Drugie imię ucznia nr ksiegi  \
# 0        1       Staśkiewicz        Anna          Magdalena      4149
# 1        2  Chicińska-Ryster      Nikola             Żaneta      4150
# 2        3            Papież    Kristian               Alan      4151
# 3        4           Kukieła      Amelia          Magdalena      4152
# 4        5            Patacz      Amelia          Michalina      1853
# ..     ...               ...         ...                ...       ...
# 98    99.0        Włodraczyk    Wiktoria                NaN      4060
# 99   100.0         Yalovskyi    Yaroslav                NaN      4061
# 100  101.0         Krawczak      Matthew              Peter      4062
# 101  102.0       Lenkiewicz      Zuzanna                NaN      4063
# 102  103.0       Radzimiński        Igor                NaN      4624
#
#     Data urodzenia ucznia         Miejsce urodzen.. PESEL ucznia  \
# 0              2007-12-07                      Piła   7320704782
# 1              2008-04-14      CHESTERFIELD ENGLAND   8241412527
# 2              2007-12-10  Reykjanesbaer - Islandia          NaN
# 3              2007-10-30             Bielsko-Biała   7303002809
# 4              2007-04-16            POLANICA ZDRÓJ   7241601308
# ..                    ...                       ...          ...
# 98             2008-04-27                     Wałcz   8242702500
# 99             2008-11-21                     Kijów   8312114459
# 100            2008-03-04                 ST.Thomas   8230413375
# 101            2008-05-09                   Londyn    8250912500
# 102            2009-04-12                  Warszawa   9241206590
#
#              Inny dokument t.. Nr i seria doku.. Kraj pobytu ucznia  \
# 0                          NaN               NaN             Niemcy
# 1                          NaN               NaN    Wielka Brytania
# 2                     Paszport         ER0669334           Islandia
# 3                          NaN               NaN             Polska
# 4    Inny dokument ze zdjęciem         CCF287398            Szwecja
# ..                         ...               ...                ...
# 98                         NaN               NaN             Turcja
# 99                         NaN               NaN            Ukraina
# 100                        NaN               NaN             Kanada
# 101                        NaN               NaN    Wielka Brytania
# 102                        NaN               NaN             Moskwa
#
#                                        Email      Klasa
# 0                     alinastaskiewicz@o2.pl   1 LO ram
# 1                              strati-matyja   1 LO ram
# 2                    kristiano2007@gmail.com   1 LO ram
# 3                                magda@wp.eu   1 LO ram
# 4                            edzia1703@o2.pl   1 LO ram
# ..                                       ...        ...
# 98                                       NaN  8 sp uzup
# 99   juliajalov@gmail.com;fogartu@qulook.com  8 sp uzup
# 100                    leskrawczak@Gmail.com  8 sp uzup
# 101                       anka_jak@yahoo.com  8 sp uzup
# 102                      a.radziminska@wp.pl  8 sp uzup
#
# [1724 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['L.p.', 'Nazwisko ucznia', 'Imię/Imiona', 'e-mail', 'Klasa'], dtype='object')

# %%
df.columns = ['L.p.', 'Nazwisko', 'Imię', 'e-mail', 'Klasa']

# %%
db.columns = ['L.p.', 'Nazwisko', 'Imię', 'Drugie imię',
       'nr_ksiegi', 'Data urodzenia', 'Miejsce ur',
       'PESEL', 'Inny dok', 'Nr i seria',
       'Kraj', 'e-mail', 'Klasa']

# %%
df
# Out:
#     L.p.          Nazwisko                Imię  \
# 1    1.0         Bembnista               Dawid
# 2    2.0         Bryliński              Bogdan
# 3    3.0  Chicińska-Ryster              Nikola
# 4    4.0             Ciźla               Nadia
# 5    5.0         Czarnocka           Nikoletta
# ..   ...               ...                 ...
# 91  91.0      Łapicz-Biedź      Zachary Oliver
# 92  92.0             Łoboz        Julia Danuta
# 93  93.0         Śladewski              Antoni
# 94  94.0         Żukrowska  Anastazja Apolonia
# 95  95.0       Lenkiewicz              Zuzanna
#
#                                    e-mail      Klasa
# 1   jolbem1978@gmail.com   tombem30@wp.pl   1 LO ram
# 2               contact@olgabrylinska.com   1 LO ram
# 3                       izabela2169@wp.pl   1 LO ram
# 4                       cpn.fit@gmail.com   1 LO ram
# 5                          tamara.c@wp.pl   1 LO ram
# ..                                    ...        ...
# 91                       wbiedz@gmail.com  8 SP uzup
# 92                         gwiazdap@op.pl  8 SP uzup
# 93             jacek.sladewski@msz.gov.pl  8 SP uzup
# 94                k.a.zukrowska@gmail.com  8 SP uzup
# 95                     anka_jak@yahoo.com  8 SP uzup
#
# [1625 rows x 5 columns]

# %%
d = df.merge(db[['Nazwisko', 'Imię', 'Drugie imię','nr_ksiegi', 'Data urodzenia', 'Miejsce ur','PESEL', 'Klasa']], on=['Nazwisko', 'Imię', 'Klasa'], how = 'left')

# %%
d
# Out:
#       L.p.          Nazwisko                Imię  \
# 0      1.0         Bembnista               Dawid
# 1      2.0         Bryliński              Bogdan
# 2      3.0  Chicińska-Ryster              Nikola
# 3      4.0             Ciźla               Nadia
# 4      5.0         Czarnocka           Nikoletta
# ...    ...               ...                 ...
# 1620  91.0      Łapicz-Biedź      Zachary Oliver
# 1621  92.0             Łoboz        Julia Danuta
# 1622  93.0         Śladewski              Antoni
# 1623  94.0         Żukrowska  Anastazja Apolonia
# 1624  95.0       Lenkiewicz              Zuzanna
#
#                                      e-mail      Klasa Drugie imię nr_ksiegi  \
# 0     jolbem1978@gmail.com   tombem30@wp.pl   1 LO ram         NaN      4184
# 1                 contact@olgabrylinska.com   1 LO ram       Piotr      4178
# 2                         izabela2169@wp.pl   1 LO ram      Żaneta      4150
# 3                         cpn.fit@gmail.com   1 LO ram         NaN      4161
# 4                            tamara.c@wp.pl   1 LO ram           s      4160
# ...                                     ...        ...         ...       ...
# 1620                       wbiedz@gmail.com  8 SP uzup         NaN       NaN
# 1621                         gwiazdap@op.pl  8 SP uzup         NaN       NaN
# 1622             jacek.sladewski@msz.gov.pl  8 SP uzup         NaN       NaN
# 1623                k.a.zukrowska@gmail.com  8 SP uzup         NaN       NaN
# 1624                     anka_jak@yahoo.com  8 SP uzup         NaN       NaN
#
#      Data urodzenia            Miejsce ur       PESEL
# 0        2007-01-12     Nakło Nad Notecią  7211200535
# 1        2008-02-11                Kraków  8221103515
# 2        2008-04-14  CHESTERFIELD ENGLAND  8241412527
# 3        2007-11-15      Schwedt nad Odrą  7311508520
# 4        2007-11-13              Warszawa  7311302964
# ...             ...                   ...         ...
# 1620            NaT                   NaN         NaN
# 1621            NaT                   NaN         NaN
# 1622            NaT                   NaN         NaN
# 1623            NaT                   NaN         NaN
# 1624            NaT                   NaN         NaN
#
# [1625 rows x 10 columns]

# %%
d.to_clipboard(index = False)

# %%
cc = pd.read_excel('../import_uczniow.xls')

# %%
cc.columns
# Out:
# Index(['Nr z dziennika', 'Imiona', 'Nazwisko', 'Płęć', 'Nr Karty',
#        'Nr księgi ucznia', 'Pesel', 'Tel Ucznia', 'e-mail ucznia',
#        'Data urodzenia', 'Miejsce urodzenia', 'Miejsce urodzenia miejscownik',
#        'Ulica i nr domu', 'Kod pocztowy i miejscowość ', 'Województwo',
#        'imię i nazwisko matki', 'numer telefonu do matki',
#        'imię i nazwisko ojca', 'numer telefonu do ojca', 'email opiekun1 ',
#        'email opiekun 2', 'uwagi ucznia'],
#       dtype='object')

# %%
dd = db.loc[db['Klasa'] =='8 sp uzup']

# %%
dd.head()
# Out:
#   L.p.    Nazwisko           Imię Drugie imię nr_ksiegi Data urodzenia  \
# 0  1.0     PIETRAS       Julianna     Jadwiga      3992     2009-05-08
# 1  2.0    Paprotny          Jerzy      Łukasz      3993     2009-02-12
# 2  3.0  Włodarczyk       Wiktoria         NaN      4060     2008-04-27
# 3  4.0       Janik            Iwo   Stanisław      3995     2009-06-20
# 4  5.0       Skóra  Jagoda Aniela         NaN      3996     2008-08-13
#
#       Miejsce ur        PESEL  Inny dok Nr i seria                 Kraj  \
# 0  Uccle, Belgia          NaN  Paszport  EH7513456               Belgia
# 1       Warszawa   9221208958       NaN        NaN  Słowenia, Ljubljana
# 2          Wałcz   8242702500       NaN        NaN        Turcja, Izmir
# 3       Warszawa   9262009897       NaN        NaN       Turcja, Ankara
# 4        Gdańska  82813037882       NaN        NaN      Wielka Brytania
#
#                      e-mail      Klasa
# 0    andrea.pietras@onet.eu  8 sp uzup
# 1       lpaprotny@gmail.com  8 sp uzup
# 2         wlodarczyka@op.pl  8 sp uzup
# 3      janikagnieszka@wp.pl  8 sp uzup
# 4  patrycjawojtkowiak@o2.pl  8 sp uzup

# %%
# Inicjalizujemy pustą ramkę danych z odpowiednimi kolumnami
cd = pd.DataFrame(columns=cc.columns)

# Przypisujemy kolumny z dd do odpowiednich kolumn w cd
cd[['Nr księgi ucznia', 'Imiona', 'Nazwisko', 'Data urodzenia', 'Miejsce urodzenia', 'Pesel', 'e-mail ucznia']] = dd[['nr_ksiegi', 'Imię', 'Nazwisko', 'Data urodzenia', 'Miejsce ur', 'PESEL', 'e-mail']]

# Zostawiamy pozostałe kolumny puste, ponieważ nie mamy dla nich danych w dd

# %%
cd.head()
# Out:
#   Nr z dziennika         Imiona    Nazwisko Płęć Nr Karty Nr księgi ucznia  \
# 0            NaN       Julianna     PIETRAS  NaN      NaN             3992
# 1            NaN          Jerzy    Paprotny  NaN      NaN             3993
# 2            NaN       Wiktoria  Włodarczyk  NaN      NaN             4060
# 3            NaN            Iwo       Janik  NaN      NaN             3995
# 4            NaN  Jagoda Aniela       Skóra  NaN      NaN             3996
#
#          Pesel Tel Ucznia             e-mail ucznia Data urodzenia  ...  \
# 0          NaN        NaN    andrea.pietras@onet.eu     2009-05-08  ...
# 1   9221208958        NaN       lpaprotny@gmail.com     2009-02-12  ...
# 2   8242702500        NaN         wlodarczyka@op.pl     2008-04-27  ...
# 3   9262009897        NaN      janikagnieszka@wp.pl     2009-06-20  ...
# 4  82813037882        NaN  patrycjawojtkowiak@o2.pl     2008-08-13  ...
#
#   Ulica i nr domu Kod pocztowy i miejscowość  Województwo  \
# 0             NaN                         NaN         NaN
# 1             NaN                         NaN         NaN
# 2             NaN                         NaN         NaN
# 3             NaN                         NaN         NaN
# 4             NaN                         NaN         NaN
#
#   imię i nazwisko matki numer telefonu do matki imię i nazwisko ojca  \
# 0                   NaN                     NaN                  NaN
# 1                   NaN                     NaN                  NaN
# 2                   NaN                     NaN                  NaN
# 3                   NaN                     NaN                  NaN
# 4                   NaN                     NaN                  NaN
#
#   numer telefonu do ojca email opiekun1  email opiekun 2 uwagi ucznia
# 0                    NaN             NaN             NaN          NaN
# 1                    NaN             NaN             NaN          NaN
# 2                    NaN             NaN             NaN          NaN
# 3                    NaN             NaN             NaN          NaN
# 4                    NaN             NaN             NaN          NaN
#
# [5 rows x 22 columns]

# %%
# Usuwamy '.0' na końcu wartości, konwertujemy na string
cd['Pesel'] = cd['Pesel'].astype(str).str.split('.').str[0]

# Uzupełniamy zera na początku do 11 cyfr
cd['Pesel'] = cd['Pesel'].str.zfill(11)

# %%
cd
# Out:
#     Nr z dziennika         Imiona     Nazwisko Płęć Nr Karty Nr księgi ucznia  \
# 0              NaN       Julianna      PIETRAS  NaN      NaN             3992
# 1              NaN          Jerzy     Paprotny  NaN      NaN             3993
# 2              NaN       Wiktoria   Włodarczyk  NaN      NaN             4060
# 3              NaN            Iwo        Janik  NaN      NaN             3995
# 4              NaN  Jagoda Aniela        Skóra  NaN      NaN             3996
# ..             ...            ...          ...  ...      ...              ...
# 98             NaN       Wiktoria   Włodraczyk  NaN      NaN             4060
# 99             NaN       Yaroslav    Yalovskyi  NaN      NaN             4061
# 100            NaN        Matthew    Krawczak   NaN      NaN             4062
# 101            NaN        Zuzanna  Lenkiewicz   NaN      NaN             4063
# 102            NaN           Igor  Radzimiński  NaN      NaN             4624
#
#            Pesel Tel Ucznia                            e-mail ucznia  \
# 0            NaN        NaN                   andrea.pietras@onet.eu
# 1     9221208958        NaN                      lpaprotny@gmail.com
# 2     8242702500        NaN                        wlodarczyka@op.pl
# 3     9262009897        NaN                     janikagnieszka@wp.pl
# 4    82813037882        NaN                 patrycjawojtkowiak@o2.pl
# ..           ...        ...                                      ...
# 98    8242702500        NaN                                      NaN
# 99    8312114459        NaN  juliajalov@gmail.com;fogartu@qulook.com
# 100   8230413375        NaN                    leskrawczak@Gmail.com
# 101   8250912500        NaN                       anka_jak@yahoo.com
# 102   9241206590        NaN                      a.radziminska@wp.pl
#
#     Data urodzenia  ... Ulica i nr domu Kod pocztowy i miejscowość   \
# 0       2009-05-08  ...             NaN                         NaN
# 1       2009-02-12  ...             NaN                         NaN
# 2       2008-04-27  ...             NaN                         NaN
# 3       2009-06-20  ...             NaN                         NaN
# 4       2008-08-13  ...             NaN                         NaN
# ..             ...  ...             ...                         ...
# 98      2008-04-27  ...             NaN                         NaN
# 99      2008-11-21  ...             NaN                         NaN
# 100     2008-03-04  ...             NaN                         NaN
# 101     2008-05-09  ...             NaN                         NaN
# 102     2009-04-12  ...             NaN                         NaN
#
#     Województwo imię i nazwisko matki numer telefonu do matki  \
# 0           NaN                   NaN                     NaN
# 1           NaN                   NaN                     NaN
# 2           NaN                   NaN                     NaN
# 3           NaN                   NaN                     NaN
# 4           NaN                   NaN                     NaN
# ..          ...                   ...                     ...
# 98          NaN                   NaN                     NaN
# 99          NaN                   NaN                     NaN
# 100         NaN                   NaN                     NaN
# 101         NaN                   NaN                     NaN
# 102         NaN                   NaN                     NaN
#
#     imię i nazwisko ojca numer telefonu do ojca email opiekun1   \
# 0                    NaN                    NaN             NaN
# 1                    NaN                    NaN             NaN
# 2                    NaN                    NaN             NaN
# 3                    NaN                    NaN             NaN
# 4                    NaN                    NaN             NaN
# ..                   ...                    ...             ...
# 98                   NaN                    NaN             NaN
# 99                   NaN                    NaN             NaN
# 100                  NaN                    NaN             NaN
# 101                  NaN                    NaN             NaN
# 102                  NaN                    NaN             NaN
#
#     email opiekun 2 uwagi ucznia
# 0               NaN          NaN
# 1               NaN          NaN
# 2               NaN          NaN
# 3               NaN          NaN
# 4               NaN          NaN
# ..              ...          ...
# 98              NaN          NaN
# 99              NaN          NaN
# 100             NaN          NaN
# 101             NaN          NaN
# 102             NaN          NaN
#
# [101 rows x 22 columns]

# %%
cd['Płęć'] = cd['Imiona'].apply(lambda x: 'K' if str(x).strip().endswith('a') else 'M')

# %%
cd
# Out:
#     Nr z dziennika         Imiona     Nazwisko Płęć Nr Karty Nr księgi ucznia  \
# 0              NaN       Julianna      PIETRAS    K      NaN             3992
# 1              NaN          Jerzy     Paprotny    M      NaN             3993
# 2              NaN       Wiktoria   Włodarczyk    K      NaN             4060
# 3              NaN            Iwo        Janik    M      NaN             3995
# 4              NaN  Jagoda Aniela        Skóra    K      NaN             3996
# ..             ...            ...          ...  ...      ...              ...
# 98             NaN       Wiktoria   Włodraczyk    K      NaN             4060
# 99             NaN       Yaroslav    Yalovskyi    M      NaN             4061
# 100            NaN        Matthew    Krawczak     M      NaN             4062
# 101            NaN        Zuzanna  Lenkiewicz     K      NaN             4063
# 102            NaN           Igor  Radzimiński    M      NaN             4624
#
#            Pesel Tel Ucznia                            e-mail ucznia  \
# 0            NaN        NaN                   andrea.pietras@onet.eu
# 1     9221208958        NaN                      lpaprotny@gmail.com
# 2     8242702500        NaN                        wlodarczyka@op.pl
# 3     9262009897        NaN                     janikagnieszka@wp.pl
# 4    82813037882        NaN                 patrycjawojtkowiak@o2.pl
# ..           ...        ...                                      ...
# 98    8242702500        NaN                                      NaN
# 99    8312114459        NaN  juliajalov@gmail.com;fogartu@qulook.com
# 100   8230413375        NaN                    leskrawczak@Gmail.com
# 101   8250912500        NaN                       anka_jak@yahoo.com
# 102   9241206590        NaN                      a.radziminska@wp.pl
#
#     Data urodzenia  ... Ulica i nr domu Kod pocztowy i miejscowość   \
# 0       2009-05-08  ...             NaN                         NaN
# 1       2009-02-12  ...             NaN                         NaN
# 2       2008-04-27  ...             NaN                         NaN
# 3       2009-06-20  ...             NaN                         NaN
# 4       2008-08-13  ...             NaN                         NaN
# ..             ...  ...             ...                         ...
# 98      2008-04-27  ...             NaN                         NaN
# 99      2008-11-21  ...             NaN                         NaN
# 100     2008-03-04  ...             NaN                         NaN
# 101     2008-05-09  ...             NaN                         NaN
# 102     2009-04-12  ...             NaN                         NaN
#
#     Województwo imię i nazwisko matki numer telefonu do matki  \
# 0           NaN                   NaN                     NaN
# 1           NaN                   NaN                     NaN
# 2           NaN                   NaN                     NaN
# 3           NaN                   NaN                     NaN
# 4           NaN                   NaN                     NaN
# ..          ...                   ...                     ...
# 98          NaN                   NaN                     NaN
# 99          NaN                   NaN                     NaN
# 100         NaN                   NaN                     NaN
# 101         NaN                   NaN                     NaN
# 102         NaN                   NaN                     NaN
#
#     imię i nazwisko ojca numer telefonu do ojca email opiekun1   \
# 0                    NaN                    NaN             NaN
# 1                    NaN                    NaN             NaN
# 2                    NaN                    NaN             NaN
# 3                    NaN                    NaN             NaN
# 4                    NaN                    NaN             NaN
# ..                   ...                    ...             ...
# 98                   NaN                    NaN             NaN
# 99                   NaN                    NaN             NaN
# 100                  NaN                    NaN             NaN
# 101                  NaN                    NaN             NaN
# 102                  NaN                    NaN             NaN
#
#     email opiekun 2 uwagi ucznia
# 0               NaN          NaN
# 1               NaN          NaN
# 2               NaN          NaN
# 3               NaN          NaN
# 4               NaN          NaN
# ..              ...          ...
# 98              NaN          NaN
# 99              NaN          NaN
# 100             NaN          NaN
# 101             NaN          NaN
# 102             NaN          NaN
#
# [101 rows x 22 columns]

# %%
cd['Imiona'] = cd['Imiona'].str.title()
cd['Nazwisko'] = cd['Nazwisko'].str.title()

# %%
cd.to_csv('klasa8uzup.csv', sep = ';', encoding = 'windows-1250', errors='ignore', index=False)
